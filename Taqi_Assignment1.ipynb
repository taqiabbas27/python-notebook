# %% [markdown]
# # ASSIGNMENT # 01

# %%
# Q1. Arithmetic Operations

a = 15
b = 4

print("Sum =", a + b)
print("Difference =", a - b)
print("Product =", a * b)
print("Division =", a / b)
print("Floor Division =", a // b)
print("Modulus =", a % b)
# Out:
# Sum = 19
# Difference = 11
# Product = 60
# Division = 3.75
# Floor Division = 3
# Modulus = 3

# %%
# Q2. Favorite Food

favorite_food = "Biryani"
print("My favorite food is", favorite_food)
# Out:
# My favorite food is Biryani

# %%
# Q3. Total Fruits

apple = '22'
mangoes = 33

total_fruits = int(apple) + mangoes
print("Total fruits =", total_fruits)
# Out:
# Total fruits = 55

# %%
# Q4. Type Checking and Conversion

num1 = 10
num2 = 5.6
num3 = 4.43
num4 = '23'

print(type(num1))
print(type(num2))
print(type(num3))
print(type(num4))

# Integer to Float
print(float(num1))

# Float to Integer
print(int(num2))

# Float to String
print(str(num3))

# String to Integer
print(int(num4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# 10.0
# 5
# 4.43
# 23

# %%
# Q5. Name and Age

name = "Taqi Abbas"
age = 19

age = age + 1

print("Name:", name)
print("Final Age:", age)
# Out:
# Name: Taqi Abbas
# Final Age: 20

# %%
# Q6. Basic Operations

a = 2
b = 1
c = 6
d = 3

print("Addition =", a + b)
print("Subtraction =", c - a)
print("Multiplication =", d * b)
print("Division =", c / d)
print("Modulus =", c % d)
print("Square of (d+a) =", (d + a) ** 2)
# Out:
# Addition = 3
# Subtraction = 4
# Multiplication = 3
# Division = 2.0
# Modulus = 0
# Square of (d+a) = 25

# %%
# Q7. Age Calculation

age = 20
age = age + 5

print("Current Age =", age)
# Out:
# Current Age = 25

# %%
# Q8. Type Conversion Operations

a = '2'
b = '11'
c = 6.3

# Convert a to integer then add to c
result1 = int(a) + c
print(result1)

# Convert b to float then multiply by c
result2 = float(b) * c
print(result2)

# Convert c to integer then add to c
result3 = int(c) + c
print(result3)
# Out:
# 8.3
# 69.3
# 12.3

# %%
# Q9. Books Remaining

books = 12
books = books - 4

print("Books left =", books)
# Out:
# Books left = 8

# %%
# Q10. Cookies Baked Today

cookies = 5
cookies = cookies * 3

print("Cookies baked today =", cookies)
# Out:
# Cookies baked today = 15

# %%
# Q11. PEDMAS Expression

result = 20 - 4 * (3 + 2) + 18 / 3

print("Answer =", result)
# Out:
# Answer = 6.0
